# %%
import boto3
import io
import csv
import sys
import pandas as pd
import numpy as np
from dataclasses import dataclass
from typing import List
from dataclasses import replace
import re
import itertools

@dataclass
class TriggerRow:
    index:str = ""
    title:str = ""
    description:str = ""


class TriggerTable:
    def __init__(self,sheet_df:pd.DataFrame)->None:
        """
        Arg:
            sheet_df:サンプルエクセルファイルをDataFrameに変換したもの
        """
        self.pj_rows:List[TriggerRow]=[]
        self.ot_rows:List[TriggerRow]=[]
        self.in_rows:List[TriggerRow]=[]
        self.fs1_rows:List[TriggerRow]=[]
        self.fs2_rows:List[TriggerRow]=[]
        
        self.extra_pj(sheet_df)
        self.extra_ot(sheet_df)
        self.extra_in(sheet_df)
        self.extra_fs1(sheet_df)
        self.extra_fs2(sheet_df)

    #PJリスト作成
    def extra_pj(self,sheet_df):
        pj_df = sheet_df[sheet_df["項目index"].str.contains("PJ")]
        self.pj_rows = [ TriggerRow(index,title,description) for index,title,description in zip(pj_df["項目index"].values,pj_df['項目'].values,pj_df['内容'].values)]
        
    
    #OTリスト作成
    def extra_ot(self,sheet_df):
       ot_df = sheet_df[sheet_df["項目index"].str.contains("OT")]
       self.ot_rows = [ TriggerRow(index,title,description) for index,title,description in zip(ot_df["項目index"].values,ot_df["項目"].values,ot_df["内容"].values)]
       
    #INリスト作成
    def extra_in(self,sheet_df):
       in_df = sheet_df[sheet_df["項目index"].str.contains("IN")]
       self.in_rows = [ TriggerRow(index,title,description) for index,title,description in zip(in_df["項目index"].values,in_df["項目"].values,in_df["内容"].values)]
       
    
    #FSリスト作成
    def extra_fs1(self,sheet_df):
    #    presence_or_absence_items = fs_presence_or_absence_list
       fs1_df = sheet_df[sheet_df["項目index"].str.contains("FS-01")]
       self.fs1_rows = [TriggerRow(index,title,description) for index,title,description 
                      in zip(fs1_df["項目index"].values,fs1_df["項目"].values,fs1_df["内容"].values)
                    #   if index in presence_or_absence_items and description == 1
                      ]
    def extra_fs2(self,sheet_df):
    #    presence_or_absence_items = fs_presence_or_absence_list
       fs2_df = sheet_df[sheet_df["項目index"].str.contains("FS-02")]
       self.fs2_rows = [TriggerRow(index,title,description) for index,title,description 
                      in zip(fs2_df["項目index"].values,fs2_df["項目"].values,fs2_df["内容"].values)]


                      
@dataclass
class CheckRule:
    name:str = ""
    fs1_condition:any=""
    fs2_condition:any=""
    pj_condition:any=""
    ot_condition:any=""
    in_condition:any=""
    flag_num:int = 0
    hit_triggers:any=""

class CheckList:
    def __init__(self,DF:pd.DataFrame)->None:
        df = DF.copy()
        self.check_rules:List[CheckRule] = ""
        self.check_rules:List[CheckRule] = [CheckRule(name,fs1_condition,fs2_condition,pj_condition,ot_condition,in_condition) for name,fs1_condition,fs2_condition,pj_condition,ot_condition,in_condition
                                           in zip(df["失敗に学ぶ"].values,df['FS1'].values,df['FS2'].values,df['PJ'].values,df['OT'].values,df['IN'].values)]
        for checkRule in self.check_rules:
            if(checkRule.fs1_condition != "" and
               checkRule.fs1_condition != "ー" and
               checkRule.fs1_condition != None and
               str(checkRule.fs1_condition) != "nan"):
                checkRule.flag_num += 1
            if(checkRule.fs2_condition != "" and
               checkRule.fs2_condition != "ー" and
               checkRule.fs2_condition != None and
               str(checkRule.fs2_condition) != "nan"):
                checkRule.flag_num += 1
            if(checkRule.pj_condition != "" and
               checkRule.pj_condition != "ー" and
               checkRule.pj_condition != None and
               str(checkRule.pj_condition) != "nan"):
                checkRule.flag_num += 1
            if(checkRule.in_condition != "" and
               checkRule.in_condition != "ー" and
               checkRule.in_condition != None and
               str(checkRule.in_condition) != "nan"):
                checkRule.flag_num += 1
            if(checkRule.ot_condition != "" and
               checkRule.ot_condition != "ー" and
               checkRule.ot_condition != None and
               str(checkRule.ot_condition) != "nan"):
                checkRule.flag_num += 1
        
    def fs1_conditions(self):  
        return [ fs_rule if fs_rule != None else fs_rule for fs_rule in self.check_rules 
                if fs_rule.fs1_condition != "" and fs_rule.fs1_condition != "ー" and fs_rule.fs1_condition != None
                and str(fs_rule.fs1_condition) != "nan" ]
    
    def fs2_conditions(self):
        return [fs_rule for fs_rule in self.check_rules 
                if fs_rule.fs2_condition != "" and fs_rule.fs2_condition != "ー" and fs_rule.fs2_condition != None
                and str(fs_rule.fs2_condition) != "nan"]

    def pj_conditions(self):
        return [pj_rule for pj_rule in self.check_rules if pj_rule.pj_condition != "ー" and pj_rule.pj_condition != None
                and str(pj_rule.pj_condition) != "nan"]
    
    def in_conditions(self):
        return [in_rule for in_rule in self.check_rules if in_rule.in_condition != "ー" and in_rule.in_condition != None
                and str(in_rule.in_condition) != "nan"]
    
    def ot_conditions(self):
        return [ot_rule for ot_rule in self.check_rules if ot_rule.ot_condition != "ー" and ot_rule.ot_condition != None
                and str(ot_rule.ot_condition) != "nan"]
        # self.ruleRows:List[RuleRow]=[ RuleRow(name,fs_condition,pj_condition,ot_condition,in_condition)
        #   for name,fs_condition,pj_condition,ot_condition,in_condition 
        #   in zip(df["失敗に学ぶ"].values,df['FS'].values,df['PJ'].values,df['OT'].values,df['IN'].values)]
        
        


AWS_ACCESS_KEY_ID='AKIAVXSADXBZL5UAIMPX'
AWS_SECRET_ACCESS_KEY='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'
Bucket = "drakebucket00521-dev"
S3_Protected_Key='protected/ap-northeast-1:7cc6a7e0-a2d0-4438-b6ab-92a414d0b8b7/'

# %%
s3 = boto3.resource('s3',
                    aws_access_key_id=AWS_ACCESS_KEY_ID,
                    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
                    region_name='ap-northeast-1')
key = "protected/ap-northeast-1:7cc6a7e0-a2d0-4438-b6ab-92a414d0b8b7/LambdaTest2/LambdaTest2_output.csv"
obj = s3.Object(Bucket,key).get()
trigger_csv = io.TextIOWrapper(io.BytesIO(obj['Body'].read()))
csv_df = pd.read_csv(trigger_csv)
indexs =csv_df.iloc[:,0]

fixed_indexs = [re.sub('-(.*\d)-','-0\\1-',index) for index in indexs]
print(f"indexes=>{list(fixed_indexs[:5])}")
csv_df['index']=fixed_indexs
print(csv_df['index'])
# Out:
# indexes=>['FS-01-001', 'FS-01-002', 'FS-01-003', 'FS-01-004', 'FS-01-005']
# 0      FS-01-001
# 1      FS-01-002
# 2      FS-01-003
# 3      FS-01-004
# 4      FS-01-005
#          ...
# 606    FS-02-087
# 607    FS-02-088
# 608    FS-02-089
# 609    FS-02-090
# 610    FS-02-091
# Name: index, Length: 611, dtype: object

# %%
book = pd.ExcelFile('trigger_table.xlsm')
input_sheet_name = book.sheet_names
sheet_df = book.parse(input_sheet_name[1])
index_df = sheet_df.iloc[:,:2]

# %%
items = [item['項目'] for n,item in index_df.iterrows() for csv in csv_df['index'] if item['項目index']==csv]
csv_df['title']=items
# Out:
#          index value                                           title
# 0    FS-01-001   NaN                                        ○地下水位　TP
# 1    FS-01-002     8                                     ○地下水位　設計GL－
# 2    FS-01-003   NaN                                           ○地盤沈下
# 3    FS-01-004     1                                         ○緩い粘性土層
# 4    FS-01-005     0                                           ○緩い砂層
# ..         ...   ...                                             ...
# 606  FS-02-087   NaN  高層建物でACWまたはそれに準じるAWを採用する場合　水密性能　鋼製建具（外部）　その他内容
# 607  FS-02-088   NaN               高層建物でACWまたはそれに準じるAWを採用する場合　遮音性　T値
# 608  FS-02-089    45               高層建物でACWまたはそれに準じるAWを採用する場合　遮音性　D値
# 609  FS-02-090   NaN         高層建物でACWまたはそれに準じるAWを採用する場合　遮音性　その他の要求性能
# 610  FS-02-091   NaN      高層建物でACWまたはそれに準じるAWを採用する場合　遮音性　その他の要求性能　内容
#
# [611 rows x 3 columns]

# %%
reindexed_df = csv_df.reindex(columns=['index','title','value'])
cols_rename_df = reindexed_df.rename(columns={'index':'項目index','title':'項目','value':'内容'})

# %%
trigger_table =TriggerTable(cols_rename_df)

# %%
trigger_table.fs1_rows
# Out:
# [TriggerRow(index='FS-01-001', title='○地下水位\u3000TP', description=nan),
#  TriggerRow(index='FS-01-002', title='○地下水位\u3000設計GL－', description='8'),
#  TriggerRow(index='FS-01-003', title='○地盤沈下', description=nan),
#  TriggerRow(index='FS-01-004', title='○緩い粘性土層', description='1'),
#  TriggerRow(index='FS-01-005', title='○緩い砂層', description='0'),
#  TriggerRow(index='FS-01-006', title='○地形特殊性', description='1'),
#  TriggerRow(index='FS-01-007', title='○地形特殊性\u3000傾斜地', description='1'),
#  TriggerRow(index='FS-01-008', title='○地形特殊性\u3000崖地隣接', description=nan),
#  TriggerRow(index='FS-01-009', title='〇地滑りリスク', description='0'),
#  TriggerRow(index='FS-01-010', title='○過去の出水', description='0'),
#  TriggerRow(index='FS-01-011', title='○過去の出水\u3000津波氾濫\u3000TP', description=nan),
#  TriggerRow(index='FS-01-012', title='○過去の出水\u3000内水氾濫\u3000TP', description=nan),
#  TriggerRow(index='FS-01-013', title='○津波リスク', description='0'),
#  TriggerRow(index='FS-01-014', title='○地中障害・土壌汚染 ', description='1'),
#  TriggerRow(index='FS-01-015', title='○地中障害・土壌汚染\u3000障害', description='1'),
#  TriggerRow(index='FS-01-016', title='○地中障害・土壌汚染\u3000汚染', description=nan),
#  TriggerRow(index='FS-01-017', title='○遺跡・埋蔵文化財など', description='0'),
#  TriggerRow(index='FS-01-018', title='○遺跡・埋蔵文化財など\u3000内容', description='人骨が発見される可能性有'),
#  TriggerRow(index='FS-01-019', title='○付近の活断層状況', description='0'),
#  TriggerRow(index='FS-01-020', title='○地震地域係数\u3000Z＝', description=nan),
#  TriggerRow(index='FS-01-021', title='○地盤種別', description='1'),
#  TriggerRow(index='FS-01-022', title='○設計震度指定', description='0'),
#  TriggerRow(index='FS-01-023', title='○最大瞬間風速', description='46.7'),
#  TriggerRow(index='FS-01-024', title='○主風向\u3000夏', description='南南東'),
#  TriggerRow(index='FS-01-025', title='○主風向\u3000夏\u3000測定場所', description='東京.'),
#  TriggerRow(index='FS-01-026', title='○主風向\u3000夏\u3000高さ', description='35.1m(北の丸)'),
#  TriggerRow(index='FS-01-027', title='○主風向\u3000冬', description='北北西'),
#  TriggerRow(index='FS-01-028', title='○主風向\u3000冬\u3000計測場所', description='東京.'),
#  TriggerRow(index='FS-01-029', title='○主風向\u3000冬\u3000高さ', description='35.1m(北の丸)'),
#  TriggerRow(index='FS-01-030', title='○地形', description='2'),
#  TriggerRow(index='FS-01-031', title='○海岸からの距離', description='5.1'),
#  TriggerRow(index='FS-01-032', title='○河川（多摩川程度）からの距離', description='2.3'),
#  TriggerRow(index='FS-01-033', title='○周辺の超高層建物', description='0'),
#  TriggerRow(index='FS-01-034', title='○最大降雨量\u300010分雨量', description='35'),
#  TriggerRow(index='FS-01-035', title='○最大降雨量\u30001時間雨量', description='88.7'),
#  TriggerRow(index='FS-01-036', title='○最大降雨量\u3000計測場所', description=nan),
#  TriggerRow(index='FS-01-037', title='○過去の雹[ひょう]害', description='0'),
#  TriggerRow(index='FS-01-038', title='○最深積雪量', description='33'),
#  TriggerRow(index='FS-01-039', title='○最深積雪量\u3000計測場所\u3000\u3000', description='東京1969年'),
#  TriggerRow(index='FS-01-040', title='〇多雪区域等', description='2'),
#  TriggerRow(index='FS-01-041', title='○雷の発生傾向', description='0'),
#  TriggerRow(index='FS-01-042', title='○想定誘導雷数\u3000', description=nan),
#  TriggerRow(index='FS-01-043', title='○想定直撃雷数', description='0.05'),
#  TriggerRow(index='FS-01-044', title='○防火地域', description='0'),
#  TriggerRow(index='FS-01-045', title='○法定耐火性', description='0'),
#  TriggerRow(index='FS-01-046', title='○法定耐火性\u3000その他内容', description=nan),
#  TriggerRow(index='FS-01-047', title='○電源バックアップ', description='1'),
#  TriggerRow(index='FS-01-048', title='○電源バックアップ\u3000対象', description='テナントOA電源1φ15VA/m2、3φ7VA/m2'),
#  TriggerRow(index='FS-01-049', title='○設備バックアップ', description=nan),
#  TriggerRow(index='FS-01-050', title='○設備バックアップ\u3000対象', description='給排水ポンプ、ELV、各階WC、機械駐車'),
#  TriggerRow(index='FS-01-051', title='○省エネルギー基準の地域区分', description='5'),
#  TriggerRow(index='FS-01-052', title='○結露防止要求', description='0'),
#  TriggerRow(index='FS-01-053', title='○在室人員・室定員', description='0.2'),
#  TriggerRow(index='FS-01-054', title='○外気量', description='30'),
#  TriggerRow(index='FS-01-055', title='○冷房\u3000［外気］\u3000温度', description='36'),
#  TriggerRow(index='FS-01-056', title='○冷房\u3000［外気］\u3000湿度', description='50'),
#  TriggerRow(index='FS-01-057', title='○冷房\u3000［室内］\u3000温度', description='25'),
#  TriggerRow(index='FS-01-058', title='○冷房\u3000［室内］\u3000湿度', description='60'),
#  TriggerRow(index='FS-01-059', title='○暖房\u3000［外気］\u3000温度', description='0'),
#  TriggerRow(index='FS-01-060', title='○暖房\u3000［外気］\u3000湿度', description='40'),
#  TriggerRow(index='FS-01-061', title='○暖房\u3000［室内］\u3000温度', description='22'),
#  TriggerRow(index='FS-01-062', title='○暖房\u3000［室内］\u3000湿度', description='40'),
#  TriggerRow(index='FS-01-063', title='○照明\u3000[設定位置]', description='600□グリッド天井照明'),
#  TriggerRow(index='FS-01-064', title='○照明\u3000照度', description='700'),
#  TriggerRow(index='FS-01-065', title='○照明\u3000照度\u3000計測場所', description='0'),
#  TriggerRow(index='FS-01-066', title='○コンセント\u3000', description='60'),
#  TriggerRow(index='FS-01-067', title='○室間遮音性能', description='0'),
#  TriggerRow(index='FS-01-068', title='○室間遮音性能\u3000D値', description='40'),
#  TriggerRow(index='FS-01-069', title='○室内暗騒音レベル', description='0'),
#  TriggerRow(index='FS-01-070', title='○室内暗騒音レベル\u3000NC値', description='45'),
#  TriggerRow(index='FS-01-071', title='○床衝撃音レベル', description=nan),
#  TriggerRow(index='FS-01-072', title='○床衝撃音レベル\u3000軽量床衝撃音LL値', description=nan),
#  TriggerRow(index='FS-01-073', title='○床衝撃音レベル\u3000重量床衝撃音LH値', description=nan),
#  TriggerRow(index='FS-01-074', title='○室内振動性能', description='0'),
#  TriggerRow(index='FS-01-075', title='○室内振動性能\u3000V値', description='50'),
#  TriggerRow(index='FS-01-076', title='○計画上の供用期間', description='50'),
#  TriggerRow(index='FS-01-077', title='○塩害\u3000\u3000海からの距離等', description='5'),
#  TriggerRow(index='FS-01-078', title='○温泉', description='0'),
#  TriggerRow(index='FS-01-079', title='○外壁清掃\u3000ガラス清掃', description=nan),
#  TriggerRow(index='FS-01-080', title='○外壁清掃\u3000サッシ清掃', description=nan),
#  TriggerRow(index='FS-01-081', title='○設備管理\u3000管理方法', description='2'),
#  TriggerRow(index='FS-01-082', title='○害虫リスク', description='0'),
#  TriggerRow(index='FS-01-083', title='○害虫リスク\u3000建物用途', description=nan),
#  TriggerRow(index='FS-01-084', title='○害虫リスク\u3000周辺環境', description=nan),
#  TriggerRow(index='FS-01-085', title='○鼠害リスク', description='0'),
#  TriggerRow(index='FS-01-086', title='○鼠害リスク\u3000地下直通通路', description=nan),
#  TriggerRow(index='FS-01-087', title='○鼠害リスク\u3000周辺環境', description=nan),
#  TriggerRow(index='FS-01-088', title='○鳥害リスク', description='0'),
#  TriggerRow(index='FS-01-089', title='○鳥害リスク\u3000周辺対策状況', description=nan),
#  TriggerRow(index='FS-01-090', title='○鳥害リスク\u3000周辺環境・飛来状況', description=nan),
#  TriggerRow(index='FS-01-091', title='○日最高気温\u3000夏季', description='30.8'),
#  TriggerRow(index='FS-01-092', title='○日最低気温\u3000冬季', description='0.9'),
#  TriggerRow(index='FS-01-093', title='○最低気温', description='0.6'),
#  TriggerRow(index='FS-01-094', title='○最低気温・計測場所', description='北の丸公園'),
#  TriggerRow(index='FS-01-095', title='○多湿地区', description='0'),
#  TriggerRow(index='FS-01-096', title='○過去の降灰', description='0'),
#  TriggerRow(index='FS-01-097', title='○発生源の距離', description=nan),
#  TriggerRow(index='FS-01-098', title='○発生源の距離\u3000高圧送電線', description=nan),
#  TriggerRow(index='FS-01-099', title='○発生源の距離\u3000幹線道路', description=nan),
#  TriggerRow(index='FS-01-100', title='○発生源の距離\u3000鉄道', description=nan),
#  TriggerRow(index='FS-01-101', title='○発生源の距離\u3000電波塔', description=nan),
#  TriggerRow(index='FS-01-102', title='○発生源の距離\u3000その他', description=nan),
#  TriggerRow(index='FS-01-103', title='○発生源の距離\u3000その他内容', description=nan),
#  TriggerRow(index='FS-01-104', title='○迷走電流', description='0'),
#  TriggerRow(index='FS-01-105', title='○ＴＶ電波障害', description='0'),
#  TriggerRow(index='FS-01-106', title='○伝播路障害', description='0'),
#  TriggerRow(index='FS-01-107', title='○航空障害', description='0'),
#  TriggerRow(index='FS-01-108', title='○航路内高さ制限', description=nan),
#  TriggerRow(index='FS-01-109', title='○外部からの特殊振動', description='0'),
#  TriggerRow(index='FS-01-110', title='○外部からの特殊振動\u3000有りの内容', description=nan),
#  TriggerRow(index='FS-01-111', title='○外部からの特殊騒音', description='0'),
#  TriggerRow(index='FS-01-112', title='○外部からの特殊騒音\u3000数値', description=nan),
#  TriggerRow(index='FS-01-113', title='○外部からの空気汚染（幹線道路沿・重工業地域）', description='0'),
#  TriggerRow(index='FS-01-114', title='○外部からの空気汚染（幹線道路沿・重工業地域）\u3000有りの内容', description=nan),
#  TriggerRow(index='FS-01-115', title='○騒音規制', description='1'),
#  TriggerRow(index='FS-01-116', title='○騒音規制\u3000昼間', description='60'),
#  TriggerRow(index='FS-01-117', title='○騒音規制\u3000夜間', description='50'),
#  TriggerRow(index='FS-01-118', title='○羽田航路変更に伴う騒音', description='0'),
#  TriggerRow(index='FS-01-119', title='浮力対策', description='0'),
#  TriggerRow(index='FS-01-120', title='床・壁の湧水・湿気対策', description='1'),
#  TriggerRow(index='FS-01-121', title='不同沈下対策', description='1'),
#  TriggerRow(index='FS-01-122', title='不同沈下対策\u3000場所', description='3'),
#  TriggerRow(index='FS-01-123', title='ﾈｶﾞﾃｨﾌﾞﾌﾘｸｼｮﾝ対策', description='0'),
#  TriggerRow(index='FS-01-124', title='液状化対策', description='1'),
#  TriggerRow(index='FS-01-125', title='液状化対策\u3000場所', description='0'),
#  TriggerRow(index='FS-01-126', title='地滑り・崩落対策', description='1'),
#  TriggerRow(index='FS-01-127', title='片土圧対策', description='1'),
#  TriggerRow(index='FS-01-128', title='浸水対策', description='0'),
#  TriggerRow(index='FS-01-129', title='浸水対策\u3000設計出水レベル  TP', description=nan),
#  TriggerRow(index='FS-01-130', title='津波対策', description='0'),
#  TriggerRow(index='FS-01-131', title='地中障害対策', description='0'),
#  TriggerRow(index='FS-01-132', title='調査', description='1'),
#  TriggerRow(index='FS-01-133', title='調査\u3000内容', description='1'),
#  TriggerRow(index='FS-01-134', title='免震', description='1'),
#  TriggerRow(index='FS-01-135', title='制振', description=nan),
#  TriggerRow(index='FS-01-136', title='耐震', description=nan),
#  TriggerRow(index='FS-01-137', title='耐震\u3000詳細', description=nan),
#  TriggerRow(index='FS-01-138', title='特殊設計法', description='2'),
#  TriggerRow(index='FS-01-139', title='特定天井', description='0'),
#  TriggerRow(index='FS-01-140', title='特定天井\u3000使用室\u3000階数', description=nan),
#  TriggerRow(index='FS-01-141', title='特定天井\u3000使用室\u3000室名', description=nan),
#  TriggerRow(index='FS-01-142', title='風圧力の設定\u3000設計用基準風速V₀', description='34'),
#  TriggerRow(index='FS-01-143', title='風圧力の設定\u3000再現期間', description='1'),
#  TriggerRow(index='FS-01-144', title='風圧力の設定\u3000地表面粗度区分', description='2'),
#  TriggerRow(index='FS-01-145', title='ピーク風力係数の設定', description='0'),
#  TriggerRow(index='FS-01-146', title='風向による計画上の配慮', description='0'),
#  TriggerRow(index='FS-01-147', title='風向による計画上の配慮\u3000内容', description=nan),
#  TriggerRow(index='FS-01-148', title='地形等による割増', description='0'),
#  TriggerRow(index='FS-01-149', title='地形等による割増\u3000内容', description=nan),
#  TriggerRow(index='FS-01-150', title='想定降雨量', description='0'),
#  TriggerRow(index='FS-01-151', title='特別な降雨量の設定', description=nan),
#  TriggerRow(index='FS-01-152', title='特別な降雨量の設定\u3000内容', description=nan),
#  TriggerRow(index='FS-01-153', title='設計最大積雪量', description='0'),
#  TriggerRow(index='FS-01-154', title='設計最大積雪量\u3000垂直積雪量', description='30'),
#  TriggerRow(index='FS-01-155', title='設計最大積雪量\u3000積雪の単位荷重', description='20'),
#  TriggerRow(index='FS-01-156', title='告示80号による割り増しの要否', description='0'),
#  TriggerRow(index='FS-01-157', title='設計用積雪荷重', description='0.6'),
#  TriggerRow(index='FS-01-158', title='吹溜 [ 荷重割増 ] 対策', description='0'),
#  TriggerRow(index='FS-01-159', title='屋根雪の処理方法', description='0'),
#  TriggerRow(index='FS-01-160', title='つらら対策', description='0'),
#  TriggerRow(index='FS-01-161', title='誘導雷対策', description='1'),
#  TriggerRow(index='FS-01-162', title='誘導雷対策\u3000内容', description='SPD'),
#  TriggerRow(index='FS-01-163', title='直撃雷対策', description='1'),
#  TriggerRow(index='FS-01-164', title='直撃雷対策\u3000内容', description='JISA42012003レベルIV'),
#  TriggerRow(index='FS-01-165', title='避難設計', description='0'),
#  TriggerRow(index='FS-01-166', title='避難設計\u3000ルートBの内容', description=nan),
#  TriggerRow(index='FS-01-167', title='避難設計\u3000ルートCの内容', description=nan),
#  TriggerRow(index='FS-01-168', title='耐火設計', description='2'),
#  TriggerRow(index='FS-01-169', title='電源対策', description='1'),
#  TriggerRow(index='FS-01-170', title='電源対策\u3000内容', description='本線・予備電源受電'),
#  TriggerRow(index='FS-01-171', title='設備対策', description='1'),
#  TriggerRow(index='FS-01-172', title='設備対策\u3000内容', description='給排水ポンプ、ELV、各階WC、機械駐車'),
#  TriggerRow(index='FS-01-173', title='省エネ案件対象', description='1'),
#  TriggerRow(index='FS-01-174', title='建築物省エネ法', description=nan),
#  TriggerRow(index='FS-01-175', title='当社目標値[環境保全計画]', description='0.8'),
#  TriggerRow(index='FS-01-176', title='誘導措置', description=nan),
#  TriggerRow(index='FS-01-177', title='誘導措置\u3000内容', description=nan),
#  TriggerRow(index='FS-01-178', title='性能向上計画認定', description=nan),
#  TriggerRow(index='FS-01-179', title='建築物省エネ法[容積特例]', description=nan),
#  TriggerRow(index='FS-01-180', title='建物配置の配慮', description='0'),
#  TriggerRow(index='FS-01-181', title='庇・バルコニー・ルーバー配置上の配慮', description='0'),
#  TriggerRow(index='FS-01-182', title='外壁断熱上の配慮', description='1'),
#  TriggerRow(index='FS-01-183', title='ガラス', description='0,1'),
#  TriggerRow(index='FS-01-184', title='サッシ', description='2'),
#  TriggerRow(index='FS-01-185', title='屋根', description='0'),
#  TriggerRow(index='FS-01-186', title='外壁', description='1'),
#  TriggerRow(index='FS-01-187', title='蓄熱システム', description='0'),
#  TriggerRow(index='FS-01-188', title='大温度差空調[高効率搬送]', description='0'),
#  TriggerRow(index='FS-01-189', title='大温度差空調[高効率搬送]\u3000内容', description='⊿t=°C'),
#  TriggerRow(index='FS-01-190', title='外気冷房', description='0'),
#  TriggerRow(index='FS-01-191', title='外気冷房\u3000内容', description=nan),
#  TriggerRow(index='FS-01-192', title='全熱交換器', description='1'),
#  TriggerRow(index='FS-01-193', title='全熱交換器\u3000内容', description=nan),
#  TriggerRow(index='FS-01-194', title='高効率空調', description='1'),
#  TriggerRow(index='FS-01-195', title='高効率空調\u3000内容', description=nan),
#  TriggerRow(index='FS-01-196', title='コージェネレーション', description='0'),
#  TriggerRow(index='FS-01-197', title='コージェネレーション\u3000内容', description=nan),
#  TriggerRow(index='FS-01-198', title='フロアフロー', description='0'),
#  TriggerRow(index='FS-01-199', title='フロアフロー\u3000\u3000内容', description=nan),
#  TriggerRow(index='FS-01-200', title='天井輻射空調', description='0'),
#  TriggerRow(index='FS-01-201', title='天井輻射空調\u3000内容', description=nan),
#  TriggerRow(index='FS-01-202', title='PAC空調用省エネ制御\u3000i-ems', description='0'),
#  TriggerRow(index='FS-01-203', title='在室検知制御', description='0'),
#  TriggerRow(index='FS-01-204', title='タイムスケジュール制御', description='1'),
#  TriggerRow(index='FS-01-205', title='高効率照明器具', description='1'),
#  TriggerRow(index='FS-01-206', title='適正照度制御', description='1'),
#  TriggerRow(index='FS-01-207', title='ゾーニング制御', description='1'),
#  TriggerRow(index='FS-01-208', title='自然エネルギー利用', description='0'),
#  TriggerRow(index='FS-01-209', title='昼光利用制御', description='0'),
#  TriggerRow(index='FS-01-210', title='雨水利用', description='0'),
#  TriggerRow(index='FS-01-211', title='太陽光発電', description='0'),
#  TriggerRow(index='FS-01-212', title='クール・ヒートチューブ', description='0'),
#  TriggerRow(index='FS-01-213', title='グラデーションブラインド', description='0'),
#  TriggerRow(index='FS-01-214', title='自然通風', description='0'),
#  TriggerRow(index='FS-01-215', title='室内の遮音対応', description='1'),
#  TriggerRow(index='FS-01-216', title='室内の遮音対応\u3000対象室', description='居室隣接機械室'),
#  TriggerRow(index='FS-01-217', title='軽量床衝撃音対応', description='0'),
#  TriggerRow(index='FS-01-218', title='軽量床衝撃音対応\u3000対象室', description=nan),
#  TriggerRow(index='FS-01-219', title='重量床衝撃音対応', description='0'),
#  TriggerRow(index='FS-01-220', title='重量床衝撃音対応\u3000対象室', description=nan),
#  TriggerRow(index='FS-01-221', title='騒音測定', description='0'),
#  TriggerRow(index='FS-01-222', title='振動対策', description='1'),
#  TriggerRow(index='FS-01-223', title='振動対策\u3000対象室', description='事務室'),
#  TriggerRow(index='FS-01-224', title='躯体：想定供用期間', description='1'),
#  TriggerRow(index='FS-01-225', title='躯体：想定供用期間\u3000年数', description='65'),
#  TriggerRow(index='FS-01-226', title='住宅性能表示劣化対策等級', description=nan),
#  TriggerRow(index='FS-01-227', title='住宅性能表示劣化対策等級\u3000内容', description=nan),
#  TriggerRow(index='FS-01-228', title='JASS5構造体の計画供用期間級', description='1'),
#  TriggerRow(index='FS-01-229', title='JASS5構造体の計画供用期間級\u3000内容', description='標準'),
#  TriggerRow(index='FS-01-230', title='その他', description=nan),
#  TriggerRow(index='FS-01-231', title='その他\u3000内容', description=nan),
#  TriggerRow(index='FS-01-232', title='塩害対策：建築', description='0'),
#  TriggerRow(index='FS-01-233', title='塩害対策：構造', description='0'),
#  TriggerRow(index='FS-01-234', title='塩害対策：設備・電気', description='1'),
#  TriggerRow(index='FS-01-235', title='塩害対策：設備・電気\u3000内容', description='0'),
#  TriggerRow(index='FS-01-236', title='塩害汚損区分：電気', description='1'),
#  TriggerRow(index='FS-01-237', title='ゴンドラ', description='0'),
#  TriggerRow(index='FS-01-238', title='ゴンドラ\u3000内容', description=nan),
#  TriggerRow(index='FS-01-239', title='光触媒活用', description='0'),
#  TriggerRow(index='FS-01-240', title='遠隔モニタリング', description='0'),
#  TriggerRow(index='FS-01-241', title='中央監視', description='1'),
#  TriggerRow(index='FS-01-242', title='防虫：外部侵入虫対策', description='0'),
#  TriggerRow(index='FS-01-243', title='防鼠：クマネズミ対策', description='0'),
#  TriggerRow(index='FS-01-244', title='防鳥：ハト対策', description='0'),
#  TriggerRow(index='FS-01-245', title='防鳥：小鳥対策', description='0'),
#  TriggerRow(index='FS-01-246', title='内部発生虫対策', description='0'),
#  TriggerRow(index='FS-01-247', title='ハツカネズミ対策', description='0'),
#  TriggerRow(index='FS-01-248', title='カラス対策', description='0'),
#  TriggerRow(index='FS-01-249', title='夏季温度対策', description='0'),
#  TriggerRow(index='FS-01-250', title='低温度対策', description='0'),
#  TriggerRow(index='FS-01-251', title='結露対策', description='1'),
#  TriggerRow(index='FS-01-252', title='冬季温度対策', description='0'),
#  TriggerRow(index='FS-01-253', title='凍結深度対策', description='0'),
#  TriggerRow(index='FS-01-254', title='凍結深度対策\u3000凍結深度', description=nan),
#  TriggerRow(index='FS-01-255', title='凍害対策', description='0'),
#  TriggerRow(index='FS-01-256', title='気温・湿度・火山：その他', description='0'),
#  TriggerRow(index='FS-01-257', title='気温・湿度・火山：その他\u3000内容', description='湿気・火山灰'),
#  TriggerRow(index='FS-01-258', title='電磁波対策', description='0'),
#  TriggerRow(index='FS-01-259', title='迷走電流対策', description='0'),
#  TriggerRow(index='FS-01-260', title='伝播路障害', description='0'),
#  TriggerRow(index='FS-01-261', title='磁気対策', description='0'),
#  TriggerRow(index='FS-01-262', title='ＴＶ電波障害対策', description='0'),
#  TriggerRow(index='FS-01-263', title='振動対策', description='0'),
#  TriggerRow(index='FS-01-264', title='騒音対策', description='0'),
#  TriggerRow(index='FS-01-265', title='空気汚染対策', description='0'),
#  TriggerRow(index='FS-01-266', title='空気汚染対策\u3000内容', description=nan),
#  TriggerRow(index='FS-01-267', title='近隣許容騒音、対策', description='1'),
#  TriggerRow(index='FS-01-268', title='航路変更に伴う騒音対策', description='0'),
#  TriggerRow(index='FS-01-269', title='航路変更に伴う騒音対策\u3000内容', description=nan),
#  TriggerRow(index='FS-01-270', title='直接基礎', description=nan),
#  TriggerRow(index='FS-01-271', title='地耐力', description=nan),
#  TriggerRow(index='FS-01-272', title='地耐力\u3000数値', description=nan),
#  TriggerRow(index='FS-01-273', title='地盤改良', description='1'),
#  TriggerRow(index='FS-01-274', title='地盤改良\u3000工法', description='テノコラム程度'),
#  TriggerRow(index='FS-01-275', title='杭基礎', description='1'),
#  TriggerRow(index='FS-01-276', title='場所打杭', description='1'),
#  TriggerRow(index='FS-01-277', title='場所打杭\u3000工法', description='アースドリル拡底工法'),
#  TriggerRow(index='FS-01-278', title='既製杭', description=nan),
#  TriggerRow(index='FS-01-279', title='既製杭\u3000工法', description=nan),
#  TriggerRow(index='FS-01-280', title='その他', description=nan),
#  TriggerRow(index='FS-01-281', title='その他\u3000内容', description=nan),
#  TriggerRow(index='FS-01-282', title='浸水対策\u3000１FLを上げる', description=nan),
#  TriggerRow(index='FS-01-283', title='浸水対策\u3000１FLを上げる\u3000数値', description=nan),
#  TriggerRow(index='FS-01-284', title='浸水対策\u3000防潮板等設備対応', description=nan),
#  TriggerRow(index='FS-01-285', title='浸水対策\u3000土嚢', description=nan),
#  TriggerRow(index='FS-01-286', title='浸水対策\u3000その他', description=nan),
#  TriggerRow(index='FS-01-287', title='浸水対策\u3000その他\u3000内容', description=nan),
#  TriggerRow(index='FS-01-288', title='耐震構造', description=nan),
#  TriggerRow(index='FS-01-289', title='耐震構造\u3000構造形式', description=nan),
#  TriggerRow(index='FS-01-290', title='耐震構造\u3000構造形式\u3000内容', description=nan),
#  TriggerRow(index='FS-01-291', title='耐震構造\u3000一次設計用ﾍﾞｰｽｼｱ係数', description=nan),
#  TriggerRow(index='FS-01-292', title='耐震構造\u3000一次設計用ﾍﾞｰｽｼｱ係数\u3000数値', description=nan),
#  TriggerRow(index='FS-01-293', title='最大層間変形角\u3000数値', description=nan),
#  TriggerRow(index='FS-01-294', title='制震構造・免震構造', description='1'),
#  TriggerRow(index='FS-01-295', title='ＰＭＬ', description=nan),
#  TriggerRow(index='FS-01-296', title='ＰＭＬ\u3000数値', description=nan),
#  TriggerRow(index='FS-01-297', title='構造形式', description=nan),
#  TriggerRow(index='FS-01-298', title='構造形式\u3000内容', description=nan),
#  TriggerRow(index='FS-01-299', title='装置', description=nan),
#  TriggerRow(index='FS-01-300', title='装置\u3000内容', description=nan),
#  TriggerRow(index='FS-01-301', title='ﾚﾍﾞﾙ1[損傷限界]', description=nan),
#  TriggerRow(index='FS-01-302', title='ﾚﾍﾞﾙ1[損傷限界]\u3000ﾍﾞｰｽｼｱ係数\u3000数値', description=nan),
#  TriggerRow(index='FS-01-303', title='ﾚﾍﾞﾙ1[損傷限界]\u3000最大層間変形角\u3000数値', description='*設計用層せん断力以下なので省略'),
#  TriggerRow(index='FS-01-304', title='ﾚﾍﾞﾙ2[損傷限界]', description='1'),
#  TriggerRow(index='FS-01-305', title='ﾚﾍﾞﾙ2[損傷限界]\u3000ﾍﾞｰｽｼｱ係数\u3000数値', description='0.24'),
#  TriggerRow(index='FS-01-306', title='ﾚﾍﾞﾙ2[損傷限界]\u3000最大層間変形角\u3000数値', description='165'),
#  TriggerRow(index='FS-01-307', title='耐風構造', description='1'),
#  TriggerRow(index='FS-01-308', title='耐風構造\u3000構造骨組用水平風荷重', description='1'),
#  TriggerRow(index='FS-01-309', title='耐風構造\u3000構造骨組用水平風荷重\u3000数値', description='3000'),
#  TriggerRow(index='FS-01-310', title='耐風構造\u3000構造骨組用水平風荷重\u3000最大層間変形角\u3000数値', description='*設計用層せん断力以下なので省略'),
#  TriggerRow(index='FS-01-311', title='特定天井', description='1'),
#  TriggerRow(index='FS-01-312', title='特定天井\u3000告示771号（吊り天井）', description=nan),
#  TriggerRow(index='FS-01-313', title='特定天井\u3000告示778号（すき間無し天井）', description=nan),
#  TriggerRow(index='FS-01-314', title='特定天井\u3000ぶどう棚直貼り（非吊天井）', description=nan),
#  TriggerRow(index='FS-01-315', title='特定天井\u3000その他の方法（認定工法、一般認定工法等）', description='1'),
#  TriggerRow(index='FS-01-316', title='一般の天井', description='1'),
#  TriggerRow(index='FS-01-317', title='一般の天井\u3000水平震度Ｋ＝1.0、垂直震度Ｋ＝0.5（1.0：吊元構造スパンが15ｍ超の場合）', description='1'),
#  TriggerRow(index='FS-01-318', title='一般の天井\u3000その他', description=nan),
#  TriggerRow(index='FS-01-319', title='一般の天井\u3000その他\u3000内容', description=nan),
#  TriggerRow(index='FS-01-320', title='外装\u3000設計条件', description='1'),
#  TriggerRow(index='FS-01-321', title='外装\u3000設計条件\u3000最大正圧', description='1'),
#  TriggerRow(index='FS-01-322', title='外装\u3000設計条件\u3000最大正圧\u3000数値', description='2457.4'),
#  TriggerRow(index='FS-01-323', title='外装\u3000設計条件\u3000最小負圧', description='1'),
#  TriggerRow(index='FS-01-324', title='外装\u3000設計条件\u3000最小負圧\u3000数値', description='1576.3'),
#  TriggerRow(index='FS-01-325', title='外装\u3000設計条件\u3000風力分布図による', description=nan),
#  TriggerRow(index='FS-01-326', title='耐風圧・水密・気密・風力係数割増しの要否ついては、性能フォローシート（設計条件整理シート）２による', description='1'),
#  TriggerRow(index='FS-01-327', title='ガラス', description='1'),
#  TriggerRow(index='FS-01-328', title='ガラス\u3000熱割れ計算実施', description=nan),
#  TriggerRow(index='FS-01-329', title='ガラス\u3000交換方法\u3000①破損時等', description='1'),
#  TriggerRow(index='FS-01-330', title='ガラス\u3000交換方法\u3000②大規模な更換時', description='1'),
#  TriggerRow(index='FS-01-331', title='ｱﾙﾐ防火戸', description='1'),
#  TriggerRow(index='FS-01-332', title='ｱﾙﾐ防火戸\u3000有無', description='1'),
#  TriggerRow(index='FS-01-333', title='ｱﾙﾐ防火戸\u3000アルミサッシ（個別認定）', description=nan),
#  TriggerRow(index='FS-01-334', title='ｱﾙﾐ防火戸\u3000スチールサッシ', description='1'),
#  TriggerRow(index='FS-01-335', title='ｱﾙﾐ防火戸\u3000防火シャッター', description=nan),
#  TriggerRow(index='FS-01-336', title='ｱﾙﾐ防火戸\u3000ドレンチャー設備', description=nan),
#  TriggerRow(index='FS-01-337', title='手すりの強度', description='1'),
#  TriggerRow(index='FS-01-338', title='手すりの強度\u3000BL', description=nan),
#  TriggerRow(index='FS-01-339', title='手すりの強度\u3000BL\u3000内容', description=nan),
#  TriggerRow(index='FS-01-340', title='手すりの強度\u3000JASS 13（グレード）', description='1'),
#  TriggerRow(index='FS-01-341', title='手すりの強度\u3000JASS 13（グレード）\u3000内容', description='0'),
#  TriggerRow(index='FS-01-342', title='手すりの強度\u3000耐風圧により強度を設計する場合は、性能フォローシート（設計条件整理シート）２による', description='1'),
#  TriggerRow(index='FS-01-343', title='金属屋根', description=nan),
#  TriggerRow(index='FS-01-344', title='金属屋根\u3000屋根勾配', description=nan),
#  TriggerRow(index='FS-01-345', title='金属屋根\u3000屋根勾配\u3000数値', description=nan),
#  TriggerRow(index='FS-01-346', title='屋根\u3000雪処理\u3000陸屋根（積雪対応）', description=nan),
#  TriggerRow(index='FS-01-347', title='屋根\u3000雪処理\u3000勾配屋根', description=nan),
#  TriggerRow(index='FS-01-348', title='屋根\u3000雪処理\u3000雪止め', description=nan),
#  TriggerRow(index='FS-01-349', title='屋根\u3000雪処理\u3000融雪', description=nan),
#  TriggerRow(index='FS-01-350', title='屋根\u3000雪処理\u3000自然滑落', description=nan),
#  TriggerRow(index='FS-01-351', title='屋根\u3000雪処理\u3000告示80号による割り増し係数（α）', description=nan),
#  TriggerRow(index='FS-01-352', title='屋根\u3000雪処理\u3000告示80号による割り増し係数（α）\u3000数値', description=nan),
#  TriggerRow(index='FS-01-353', title='屋根\u3000雪処理\u3000段屋根等の特段の配慮が必要な場合のレベル係数（Ｘ）', description=nan),
#  TriggerRow(index='FS-01-354', title='屋根\u3000雪処理\u3000段屋根等の特段の配慮が必要な場合のレベル係数（Ｘ）\u3000数値', description=nan),
#  TriggerRow(index='FS-01-355', title='設備機器［一般機器］', description='1'),
#  TriggerRow(index='FS-01-356', title='設備機器［一般機器］\u3000水平震度', description='0'),
#  TriggerRow(index='FS-01-357', title='設備機器［一般機器］\u3000鉛直震度', description='0'),
#  TriggerRow(index='FS-01-358', title='設備機器［一般機器］\u3000鉛直震度\u3000その他内容', description=nan),
#  TriggerRow(index='FS-01-359', title='設備機器［重要機器］', description='1'),
#  TriggerRow(index='FS-01-360', title='設備機器［重要機器］\u3000水平震度', description='0'),
#  TriggerRow(index='FS-01-361', title='設備機器［重要機器］\u3000鉛直震度', description='1'),
#  TriggerRow(index='FS-01-362', title='設備機器［重要機器］\u3000鉛直震度\u3000その他内容', description=nan),
#  TriggerRow(index='FS-01-363', title='水槽', description='1'),
#  TriggerRow(index='FS-01-364', title='水槽\u3000水平震度', description='0'),
#  TriggerRow(index='FS-01-365', title='水槽\u3000鉛直震度', description='1'),
#  TriggerRow(index='FS-01-366', title='水槽\u3000鉛直震度\u3000その他内容', description=nan),
#  TriggerRow(index='FS-01-367', title='昇降機', description='1'),
#  TriggerRow(index='FS-01-368', title='昇降機\u3000水平震度', description='1'),
#  TriggerRow(index='FS-01-369', title='外構雨量', description='1'),
#  TriggerRow(index='FS-01-370', title='外構雨量\u3000内容', description='1'),
#  TriggerRow(index='FS-01-371', title='外構雨量\u3000内容\u3000自由記述', description='240'),
#  TriggerRow(index='FS-01-372', title='避雷設備', description='1'),
#  TriggerRow(index='FS-01-373', title='避雷設備\u3000保護レベル', description='3'),
#  TriggerRow(index='FS-01-374', title='避雷設備\u3000保護レベル\u3000その他内容', description=nan),
#  TriggerRow(index='FS-01-375', title='避難設計', description=nan),
#  TriggerRow(index='FS-01-376', title='避難設計\u3000内容', description=nan),
#  TriggerRow(index='FS-01-377', title='避難設計\u3000ルートＣ\u3000階避難時間\u3000時間', description=nan),
#  TriggerRow(index='FS-01-378', title='避難設計\u3000ルートＣ\u3000階避難時間\u3000階数', description=nan),
#  TriggerRow(index='FS-01-379', title='避難設計\u3000ルートＣ\u3000全館避難時間\u3000時間', description=nan),
#  TriggerRow(index='FS-01-380', title='耐火設計', description='1'),
#  TriggerRow(index='FS-01-381', title='耐火設計\u3000内容', description='2'),
#  TriggerRow(index='FS-01-382', title='耐火設計\u3000ルートＡ\u3000耐火1ｈ\u3000階数\u3000from', description='~階、2h:~階、3h:~階'),
#  TriggerRow(index='FS-01-383', title='耐火設計\u3000ルートＡ\u3000耐火1ｈ\u3000階数\u3000to', description='耐火1h:~'),
#  TriggerRow(index='FS-01-384', title='耐火設計\u3000ルートＡ\u3000耐火2ｈ\u3000階数\u3000from', description='~階、3h:~階'),
#  TriggerRow(index='FS-01-385', title='耐火設計\u3000ルートＡ\u3000耐火2ｈ\u3000階数\u3000to', description='耐火1h:~'),
#  TriggerRow(index='FS-01-388', title='耐火設計\u3000ルートC\u3000主要耐火時間\u3000時間', description=nan),
#  TriggerRow(index='FS-01-389', title='耐火設計\u3000ルートC\u3000主要耐火時間\u3000内容', description='3~8階、部位柱、免震階鉄骨梁'),
#  TriggerRow(index='FS-01-390', title='建築物省エネ法\u3000非住宅、住宅共用部\u3000一次エネルギー消費量', description=nan),
#  TriggerRow(index='FS-01-391', title='建築物省エネ法\u3000非住宅、住宅共用部\u3000一次エネルギー消費量\u3000内容', description=nan),
#  TriggerRow(index='FS-01-392', title='建築物省エネ法\u3000非住宅、住宅共用部\u3000エネルギー利用効率化設備', description=nan),
#  TriggerRow(index='FS-01-393', title='建築物省エネ法\u3000非住宅、住宅共用部\u3000エネルギー利用効率化設備\u3000内容', description=nan),
#  TriggerRow(index='FS-01-394', title='建築物省エネ法\u3000非住宅、住宅共用部\u3000誘導基準', description=nan),
#  TriggerRow(index='FS-01-395', title='建築物省エネ法\u3000非住宅、住宅共用部\u3000誘導基準\u3000内容', description=nan),
#  TriggerRow(index='FS-01-396', title='建築物省エネ法\u3000住宅部[性能基準]\u3000UA、ηA', description=nan),
#  TriggerRow(index='FS-01-397', title='建築物省エネ法\u3000住宅部[性能基準]\u3000UA\u3000数値', description=nan),
#  TriggerRow(index='FS-01-398', title='建築物省エネ法\u3000住宅部[性能基準]\u3000ηA、数値', description=nan),
#  TriggerRow(index='FS-01-399', title='建築物省エネ法\u3000住宅部[性能基準]\u3000一次エネルギー消費量', description=nan),
#  TriggerRow(index='FS-01-400', title='建築物省エネ法\u3000住宅部[性能基準]\u3000一次エネルギー消費量\u3000内容', description=nan),
#  TriggerRow(index='FS-01-401', title='建築物省エネ法\u3000住宅部[性能基準]\u3000エネルギー利用効率化設備', description=nan),
#  TriggerRow(index='FS-01-402', title='建築物省エネ法\u3000住宅部[性能基準]\u3000エネルギー利用効率化設備\u3000内容', description=nan),
#  TriggerRow(index='FS-01-403', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000屋根断熱', description=nan),
#  TriggerRow(index='FS-01-404', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000屋根断熱\u3000熱貫流率', description=nan),
#  TriggerRow(index='FS-01-405', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000屋根断熱\u3000材料厚さ', description=nan),
#  TriggerRow(index='FS-01-406', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000外壁断熱', description=nan),
#  TriggerRow(index='FS-01-407', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000外壁断熱\u3000熱貫流率', description=nan),
#  TriggerRow(index='FS-01-408', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000外壁断熱\u3000材料厚さ', description=nan),
#  TriggerRow(index='FS-01-409', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000ガラス', description=nan),
#  TriggerRow(index='FS-01-410', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000ガラス\u3000熱貫流率', description=nan),
#  TriggerRow(index='FS-01-411', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000ガラス\u3000日射熱取得率/日射侵入率', description=nan),
#  TriggerRow(index='FS-01-412', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000住戸形状', description=nan),
#  TriggerRow(index='FS-01-413', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000外皮等面積/床面積', description=nan),
#  TriggerRow(index='FS-01-414', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000暖房[空調]', description=nan),
#  TriggerRow(index='FS-01-415', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000暖房[空調]\u3000内容', description=nan),
#  TriggerRow(index='FS-01-416', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000冷房', description=nan),
#  TriggerRow(index='FS-01-417', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000冷房\u3000内容', description=nan),
#  TriggerRow(index='FS-01-418', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000暖房[空調]', description=nan),
#  TriggerRow(index='FS-01-421', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000換気\u3000内容', description=nan),
#  TriggerRow(index='FS-01-422', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000照明', description=nan),
#  TriggerRow(index='FS-01-423', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000照明\u3000内容', description=nan),
#  TriggerRow(index='FS-01-424', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000給湯', description=nan),
#  TriggerRow(index='FS-01-425', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000給湯\u3000内容', description=nan),
#  TriggerRow(index='FS-01-426', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000昇降機', description=nan),
#  TriggerRow(index='FS-01-427', title='建築物省エネ法\u3000住宅部[仕様基準]\u3000昇降機\u3000内容', description=nan),
#  TriggerRow(index='FS-01-429', title='熱源\u3000冷凍能力', description=nan),
#  TriggerRow(index='FS-01-430', title='室内騒音\u3000間仕切壁・戸境壁', description='1'),
#  TriggerRow(index='FS-01-431', title='室内騒音\u3000間仕切壁・戸境壁\u3000遮音壁', description=nan),
#  TriggerRow(index='FS-01-432', title='室内騒音\u3000間仕切壁・戸境壁\u3000遮音壁\u3000内容', description='TLD-40(D-50)'),
#  TriggerRow(index='FS-01-433', title='室内騒音\u3000天井', description=nan),
#  TriggerRow(index='FS-01-434', title='室内騒音\u3000天井\u3000内容', description=nan),
#  TriggerRow(index='FS-01-435', title='室内騒音\u3000天井\u3000その他内容', description=nan),
#  TriggerRow(index='FS-01-436', title='室内騒音\u3000床', description='1'),
#  TriggerRow(index='FS-01-437', title='室内騒音\u3000床\u3000スラブ厚', description='1'),
#  TriggerRow(index='FS-01-438', title='室内騒音\u3000床\u3000スラブ厚\u3000内容', description='165、150'),
#  TriggerRow(index='FS-01-439', title='室内騒音\u3000床\u3000直床', description=nan),
#  TriggerRow(index='FS-01-440', title='室内騒音\u3000床\u3000二重床', description=nan),
#  TriggerRow(index='FS-01-441', title='室内騒音\u3000床\u3000二重床\u3000遮音タイプ', description=nan),
#  TriggerRow(index='FS-01-442', title='室内騒音\u3000サッシ・ガラス・建具の遮音性については性能フォローシート（設計条件整理シート）２による', description='1'),
#  TriggerRow(index='FS-01-443', title='振動\u3000躯体縁切り', description=nan),
#  TriggerRow(index='FS-01-444', title='振動\u3000浮床', description=nan),
#  TriggerRow(index='FS-01-445', title='振動\u3000防振対策', description=nan),
#  TriggerRow(index='FS-01-446', title='振動\u3000その他', description=nan),
#  TriggerRow(index='FS-01-447', title='コンクリート', description='1'),
#  TriggerRow(index='FS-01-448', title='コンクリート\u3000材料', description='普通コンクリート'),
#  TriggerRow(index='FS-01-449', title='コンクリート\u3000単位水量', description=nan),
#  TriggerRow(index='FS-01-450', title='コンクリート\u3000水セメント比', description=nan),
#  TriggerRow(index='FS-01-451', title='コンクリート\u3000品質基準強度', description='21,30'),
#  TriggerRow(index='FS-01-452', title='コンクリート\u3000コンクリート乾燥収縮率', description=nan),
#  TriggerRow(index='FS-01-453', title='鉄筋かぶり', description=nan),
#  TriggerRow(index='FS-01-454', title='鉄筋かぶり\u3000かぶり厚への配慮', description=nan),
#  TriggerRow(index='FS-01-455', title='鉄筋かぶり\u3000鉄筋防錆仕様', description=nan),
#  TriggerRow(index='FS-01-456', title='溶融亜鉛めっき', description='1'),
#  TriggerRow(index='FS-01-457', title='溶融亜鉛めっき\u3000部位', description=nan),
#  TriggerRow(index='FS-01-458', title='溶融亜鉛めっき\u3000付着量', description='1'),
#  TriggerRow(index='FS-01-459', title='電気亜鉛めっき', description=nan),
#  TriggerRow(index='FS-01-460', title='電気亜鉛めっき\u3000部位', description=nan),
#  TriggerRow(index='FS-01-461', title='電気亜鉛めっき\u3000付着量', description=nan),
#  TriggerRow(index='FS-01-462', title='本体鉄骨', description='1'),
#  TriggerRow(index='FS-01-463', title='本体鉄骨\u3000防錆処理\u3000錆止塗装', description='1'),
#  TriggerRow(index='FS-01-464', title='本体鉄骨\u3000防錆処理\u3000溶融亜鉛めっき', description='1'),
#  TriggerRow(index='FS-01-465', title='本体鉄骨\u3000防錆処理\u3000その他', description=nan),
#  TriggerRow(index='FS-01-466', title='本体鉄骨\u3000防錆処理\u3000その他内容', description=nan),
#  TriggerRow(index='FS-01-467', title='本体鉄骨\u3000防錆部位\u3000柱', description='1'),
#  TriggerRow(index='FS-01-468', title='本体鉄骨\u3000防錆部位\u3000梁', description='1'),
#  TriggerRow(index='FS-01-469', title='本体鉄骨\u3000防錆部位\u3000ブレース', description='1'),
#  TriggerRow(index='FS-01-470', title='付帯鉄骨', description='1'),
#  TriggerRow(index='FS-01-471', title='付帯鉄骨\u3000溶融亜鉛めっき（冠壁、設備架台）', description='1'),
#  TriggerRow(index='FS-01-472', title='付帯鉄骨\u3000錆止塗装（外周まわり）', description=nan),
#  TriggerRow(index='FS-01-473', title='架台ブラケット', description='1'),
#  TriggerRow(index='FS-01-474', title='架台ブラケット\u3000屋外', description='1'),
#  TriggerRow(index='FS-01-475', title='架台ブラケット\u3000屋外（溶融亜鉛めっき）\u3000付着量', description='1'),
#  TriggerRow(index='FS-01-476', title='架台ブラケット\u3000屋内', description='1'),
#  TriggerRow(index='FS-01-477', title='架台ブラケット\u3000屋内\u3000錆止塗装２回', description='1'),
#  TriggerRow(index='FS-01-478', title='架台ブラケット\u3000屋内\u3000溶融亜鉛めっき製', description=nan),
#  TriggerRow(index='FS-01-479', title='架台ブラケット\u3000取付ボルト', description='1'),
#  TriggerRow(index='FS-01-480', title='架台ブラケット\u3000屋外（ステンレス鋼製）', description='1'),
#  TriggerRow(index='FS-01-481', title='防虫\u3000外部侵入', description=nan),
#  TriggerRow(index='FS-01-482', title='防虫\u3000外部侵入\u3000低誘虫照明', description=nan),
#  TriggerRow(index='FS-01-483', title='防虫\u3000外部侵入\u3000風除室ドア隙間', description=nan),
#  TriggerRow(index='FS-01-484', title='防虫\u3000外部侵入\u3000捕虫器コンセント', description=nan),
#  TriggerRow(index='FS-01-485', title='防虫\u3000外部侵入\u3000防虫区画', description=nan),
#  TriggerRow(index='FS-01-486', title='防虫\u3000外部侵入\u3000全熱交換器フィルター', description=nan),
#  TriggerRow(index='FS-01-487', title='防虫\u3000外部侵入\u3000建物陽圧化', description=nan),
#  TriggerRow(index='FS-01-488', title='防虫\u3000外部侵入\u3000その他', description=nan),
#  TriggerRow(index='FS-01-489', title='防虫\u3000内部発生', description=nan),
#  TriggerRow(index='FS-01-490', title='防虫\u3000内部発生\u3000内壁・巾木隙間', description=nan),
#  TriggerRow(index='FS-01-491', title='防虫\u3000内部発生\u3000床のＲ化', description=nan),
#  TriggerRow(index='FS-01-492', title='防虫\u3000内部発生\u3000ＨＡＣＣＰ桝', description=nan),
#  TriggerRow(index='FS-01-493', title='防虫\u3000内部発生\u3000その他', description=nan),
#  TriggerRow(index='FS-01-494', title='防鼠\u3000防鼠対策', description=nan),
#  TriggerRow(index='FS-01-495', title='防鼠\u3000防鼠対策\u3000超音波忌避装置コンセント', description=nan),
#  TriggerRow(index='FS-01-496', title='防鼠\u3000防鼠対策\u3000その他', description=nan),
#  TriggerRow(index='FS-01-497', title='防鳥\u3000防鳥対策', description=nan),
#  TriggerRow(index='FS-01-498', title='防鳥\u3000防鳥対策\u3000ワイヤー', description=nan),
#  TriggerRow(index='FS-01-499', title='防鳥\u3000防鳥対策\u3000剣山型防鳥器具', description=nan),
#  TriggerRow(index='FS-01-500', title='防鳥\u3000防鳥対策\u3000ネット', description=nan),
#  TriggerRow(index='FS-01-501', title='防鳥\u3000防鳥対策\u3000その他', description=nan),
#  TriggerRow(index='FS-01-502', title='電磁シールド', description=nan),
#  TriggerRow(index='FS-01-503', title='電磁シールド\u3000電磁遮蔽性', description=nan),
#  TriggerRow(index='FS-01-504', title='磁気シールド', description=nan),
#  TriggerRow(index='FS-01-505', title='磁気シールド\u3000磁気遮蔽性', description=nan),
#  TriggerRow(index='FS-01-506', title='寒冷地対応', description=nan),
#  TriggerRow(index='FS-01-507', title='寒冷地対応\u3000受水槽', description=nan),
#  TriggerRow(index='FS-01-508', title='寒冷地対応\u3000配管', description=nan),
#  TriggerRow(index='FS-01-509', title='寒冷地対応\u3000衛生機器', description=nan),
#  TriggerRow(index='FS-01-510', title='寒冷地対応\u3000空調機器', description=nan),
#  TriggerRow(index='FS-01-511', title='寒冷地対応\u3000その他', description=nan),
#  TriggerRow(index='FS-01-512', title='近隣対応', description='1'),
#  TriggerRow(index='FS-01-513', title='近隣対応\u3000発生騒音レベル', description=nan),
#  TriggerRow(index='FS-01-514', title='近隣対応\u3000発生騒音レベル\u3000数値', description=nan),
#  TriggerRow(index='FS-01-515', title='近隣対応\u3000排気', description='1'),
#  TriggerRow(index='FS-01-516', title='近隣対応\u3000排気\u3000厨房', description=nan),
#  TriggerRow(index='FS-01-517', title='近隣対応\u3000排気\u3000WC', description='1'),
#  TriggerRow(index='FS-01-518', title='近隣対応\u3000排気\u3000喫煙', description='1'),
#  TriggerRow(index='FS-01-519', title='近隣対応\u3000排気\u3000自家発', description=nan),
#  TriggerRow(index='FS-01-520', title='近隣対応\u3000排気\u3000ゴミ置場', description='1'),
#  TriggerRow(index='FS-01-521', title='近隣対応\u3000排気\u3000その他', description='1'),
#  TriggerRow(index='FS-01-522', title='近隣対応\u3000排気\u3000その他内容', description='将来厨房'),
#  TriggerRow(index='FS-01-523', title='外装防汚対策', description='1'),
#  TriggerRow(index='FS-01-524', title='外装防汚対策\u3000防汚塗装', description=nan),
#  TriggerRow(index='FS-01-525', title='外装防汚対策\u3000水切・ディテール', description='1')]
